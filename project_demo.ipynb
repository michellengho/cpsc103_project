# %% [markdown]
# ### CPSC 103: PROJECT DEMO
#  **Medical Insurance Data Analysis**
#  >Michelle Ho (Section 201)

# %% [markdown]
# **Overview:** Give an overview of your project. What problem are you solving? Where is the information from? Why is it interesting to you?
#
# >The objective for my project was to determine how BMI (of the principal individual covered under the insurance) and the number of children (ie., number of dependents) influence medical charges per indiviudal covered. The significant computation that was performed was medical charges divided by the number of dependents + 1. A scatterplot will be used to graph body mass index (BMI) on the x-axis and the average medical charges per indiviudal covered (medical charges / number of dependents + 1) on the y-axis; the number of children that the principal individual has was represented by colouring the points ( the legend will only include each number of children that is contained in the data set).
#
# >From a research article, "Association of parental body mass index (BMI) with child’s health behaviors and child’s BMI depend on child’s age", a parent's and their child's BMI is found to be strongly correlated, although the relationship may vary by the child's sex and age. Thus, how the BMI of the principal individual covered and the number of children they have influence the average medical cost of each individual (the principal individual and their dependents) will be explored.
# The information file that will be used in this analysis is called "Medical Insurance Dataset" retrieved from Kaggle; it is an open-source dataset that contains 1338 rows of data with no missing or undefined values. This topic is interesting to me because I intend to pursue a career in the healthcare industry and understanding how body masss index influences medical charges in countries where people have to pay for healthcare insurance also corresponds to how BMI may affect the someones’ health status.

# %% [markdown]
# **Design Choices:** Explain how you used what you learned about systematic program design to solve the problem. What design choices did you have to make? Why did you make the choices that you made? Design choices refer to why you decided to approach a problem in a particular way (how did you decide on the various composition steps? If you had to redo the project, what would you change?)
#
# >The How to Design Data Definitions recipe was used to insert the data from the file into its appropriate form for the program; and the How to Design Functions was used to build the functions within the program to analyze the data. These systematic program design instructions provided the foundation for the project which made developing it straightforward. The final product was also organized because of the systematic designing process: all of the functions have their distinctive task due to the one-task per function rule. The purpose of each function also provided the necessary detail about what each function did such that others reading the program can understand what is going on.
#
# >The design choices that I decided to make was to incorporate helper functions for the analyze function which was to be called as composition in the main function. This decision was made because the analysis of the data required several steps, from extracting the data from the compound observation to using the data in the major computation. If the list extractions and all of the major computations had to be done within a single function, it would reduce the readability of the program. Moreover, it would have made the program difficult to modify in the future (eg. if a different variable was to be graphed against average medical charges instead of body mass index).
#
# ``` python
# @typecheck
# def graph_bmi_vs_medical_charges(filename: str) -> None:
#     """
#     reads the file from given filename, analyzes the data, and produces a scatterplot of body mass index (BMI)
#     (of the principal individual covered under the insurance) and the average medical charges per indiviudal covered
#     (medical charges / (number of dependents *ie., number of children* + 1)); it will be colored by category of number
#     of children that the principal individual has; returns None
#     """
#     # template from HtDAP, based on composition
#     return scatterplot_bmi_vs_charges(read(filename))
#
# start_testing()
# expect(graph_bmi_vs_medical_charges("medical_insurance_data_empty.csv"), None)
# expect(graph_bmi_vs_medical_charges("medical_insurance_data_test1.csv"), None)
# expect(graph_bmi_vs_medical_charges("medical_insurance_data_test2.csv"), None)
# expect(graph_bmi_vs_medical_charges("medical_insurance_data_test3.csv"), None)
# expect(graph_bmi_vs_medical_charges("medical_insurance_data_test_na.csv"), None)
# summary()
# ```

# %% [markdown]
# **Problem Solving:** Describe how you solved the problem. Provide visuals if possible, and definitely provide the graph or chart(s) that your program created.
#
# >The problem of determining how BMI (of the principal individual covered under the insurance) and the number of children (ie., number of dependents) influence medical charges per indiviudal covered was solved with a visualization. Due to the fact that a relationship is being examined between variables, a scatter plot provided the necessary information. The program reads a file from given filename, analyzes the data, and produces a scatterplot of body mass index (BMI) (of the principal individual covered under the insurance) and the average medical charges per indiviudal covered (medical charges / (number of dependents *ie., number of children* + 1)). The graph was then colored by the category of number of children that the principal individual has in order to also determine the relationship of how the number of children may influence medical charges.
#
# >A scatterplot was produced by the program and showed that there is no relationship between body mass index and the average medical costs per person. However, the more people that were covered under the medical insurance, the cheaper it became for each person on average. If only one person were covered under the plan, their medical insurance costs were significantly higher than if multiple dependents joined the insurance plan. The graph also shows the distribution of the possible range of BMI values and the range of average medical insurance costs in the data set. BMI is spread approximately 15 to 50; average medical costs are clustered at 0 to 30,000 USD.
#
# ![cpsc103 graph.png](attachment:3ceeb5d4-0c9f-48f0-8192-536e8b13af12.png)

# %% [markdown]
# **Most Challenging:** Discuss which part of the project was the most difficult for you and why.
#
# >The most difficult part of the project was producing the scatterplot with the plot aesthetic of colouring by category. It was intended for all of number of children to be in the legend of the graph (ie., there should have been discrete colours for 0-5 children in the legend and this should have been consistent across all graphs). Yet, the scatterplot function includes code for the legend that only shows the number of children that are plotted on the graph (not all colours 0-5 are shown if there are no data points with some number(s) of children—eg. if there are no individuals with 2 children in the data set, then the colour and label for 2 kids will not appear in the legend.
#
# >Moreover, the colours used to map the number of children change for the legend of each plot generated; comparing the relationships between graphs may be difficult to do. Nonetheless, the code to colour the points with the same corresponding number of children between graphs is too complicated for this course; hence, it is not done here. The hand-drawn graphs for each of the tests also have different colour preferences; however, the resulting graphs should have the appropriate colours corresponding to the number of children in the legend of the particular graph.
#
# ``` python
# @typecheck
# def scatterplot_bmi_vs_charges(lomi: List[MedicalInsurance]) -> None:
#     """
#     produces a scatterplot of body mass index (BMI) vs. the average medical charges per indiviudal covered
#     assumes that len(bmi) == len(charges), ie., bmi and charges have the same number of elements; returns None
#
#     the plot aesthetics color by category of number of children that the principal individual has
#     (legend will only include the number of children that is contained in the data set—eg. if there are no
#     individuals with 2 children in the data set, then the colour and label for 2 kids will not appear in the legend)
#     """
#     # return None  #stub
#     # template based on visualization and composition
#
#     bmi = list_bmi(lomi)
#     average_medical_charges = list_average_medical_charges(lomi)
#     children = list_children(lomi)
#     # plt.scatter(bmi, average_medical_charges, marker='o', c = children, label=['0','1','2','3','4','5')
#     # plt.legend([0, 1, 2, 3, 4, 5], title = "Number of Children", loc = 2)
#     # plt.legend()
#     fig, ax = plt.subplots()
#     scatter = ax.scatter(bmi, average_medical_charges, c = children)
#     if len(children)!=0:
#         legend1 = ax.legend(*scatter.legend_elements(), loc=2, title="Number of Children")
#         ax.add_artist(legend1)
#     # plt.show()
#
#     # plot aesthetics
#     plt.title("Body Mass Index (BMI) vs. Average Medical Charges (USD)")
#     plt.xlabel("Body Mass Index (BMI)")
#     plt.ylabel("Average Medical Charges (USD)")
#     plt.axis([0, 70, 0, 70000])
#
#     plt.show()
#     return
# ```

# %% [markdown]
# **Future Work:** Provide examples of ways in which you could use your systematic programming design skills to solve problems in your chosen topic area in the future.
#
# >In the chosen topic area of healthcare insurance, the systematic programming design skills that were learned and cultivated via this class can be used to solve problems such as:
#
# - Finding the average medical insurance charges for smokers vs. non-smokers. The significant computation will be adding up the total medical charges for each group and dividing it by the number of people within each smoking status. A bar plot may be used to represent this analysis by putting smoking status as groups on the x-axis and the average medical charges on the y-axis. If possible, the plot will be coloured according to the group smoking status.
# - Finding the average medical insurance charges for male vs. female. The significant computation will be adding up the total medical charges for each group and dividing it by the number of people within each sex. A bar plot may be used to represent this analysis by putting sex as groups on the x-axis and the average medical charges on the y-axis. If possible, the plot will be coloured according to the groups, sex.
# - Computing the proportions of people in various age groups insured by the insurance company that provided the given dataset. The significant computation will be filtering the people covered by the insurance company by age groups, eg., 0-20, 20-40, 40-60 etc., and determining the percentage that the people in each group make up from the total number of people. The proportions may be represented in a pie chart with a legend indicating the age groups chosen for the analysis. Moreover, the graph may indicate the specific percentages on each section of the pie chart to make the visualization clear.
# - Examining the relationship between sex and average BMI. The significant computation will be the summation of BMI for each group and dividing it by the number of people within each sex. A bar plot may be used to represent this analysis by putting sex as groups on the x-axis and the BMI on the y-axis. If possible, the plot will be coloured according to the groups, sex.
#
# >Overall, the relationship between the average medical costs and other variables can be examined with the current code by replacing the x-axis parameter in the graphing function: scatterplot_bmi_vs_charges.
